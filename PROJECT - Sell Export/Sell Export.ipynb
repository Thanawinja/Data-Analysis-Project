# %% [markdown]
# Import Data & Library

# %%
# Import Library

from statistics import *
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import calendar
from datetime import datetime
import sklearn
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# Check Version

print(f'pandas version: {pd.__version__}')
print(f'numpy version: {np.__version__}')
print(f'seaborn version: {sns.__version__}')
print(f'sklearn version: {sklearn.__version__}')
# Out:
# pandas version: 1.4.4
# numpy version: 1.21.5
# seaborn version: 0.11.2
# sklearn version: 1.0.2

# %%
# Import data 

data = pd.read_csv("data.csv")

# %% [markdown]
# EDA (Exploratory Data Analysis)

# %%
# Check Rows and Columns of data

data.shape
# Out:
# (1500014, 15)

# %%
# First 5 rows of data

data.head()
# Out:
#    Unnamed: 0                        Region           Country Item Type  \
# 0           0            Sub-Saharan Africa      South Africa    Fruits
# 1           1            Sub-Saharan Africa      South Africa    Fruits
# 2           2  Middle East and North Africa           Morocco   Clothes
# 3           3  Middle East and North Africa           Morocco   Clothes
# 4           4         Australia and Oceania  Papua New Guinea      Meat
#
#   Sales Channel Order Priority Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              M  7/27/2012  443368995   7/28/2012        1593
# 1       Offline              M  7/27/2012  443368995   7/28/2012        1593
# 2        Online              M  9/14/2013  667593514  10/19/2013        4611
# 3        Online              M  9/14/2013  667593514  10/19/2013        4611
# 4       Offline              M  5/15/2015  940995585    6/4/2015         360
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 0        9.33       6.92       14862.69    11023.56       3839.13
# 1        9.33       6.92       14862.69    11023.56       3839.13
# 2      109.28      35.84      503890.08   165258.24     338631.84
# 3      109.28      35.84      503890.08   165258.24     338631.84
# 4      421.89     364.69      151880.40   131288.40      20592.00

# %%
# Drop Columns

data = data.drop(columns=['Unnamed: 0'])

# %%
# Browse Data

data
# Out:
#                                     Region           Country  Item Type  \
# 0                       Sub-Saharan Africa      South Africa     Fruits
# 1                       Sub-Saharan Africa      South Africa     Fruits
# 2             Middle East and North Africa           Morocco    Clothes
# 3             Middle East and North Africa           Morocco    Clothes
# 4                    Australia and Oceania  Papua New Guinea       Meat
# ...                                    ...               ...        ...
# 1500009                               Asia             India     Snacks
# 1500010              Australia and Oceania               NaN  Household
# 1500011  Central America and the Caribbean               NaN  Household
# 1500012                               Asia            Brunei     Cereal
# 1500013       Middle East and North Africa            Israel  Beverages
#
#         Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0             Offline              M   7/27/2012  443368995   7/28/2012
# 1             Offline              M   7/27/2012  443368995   7/28/2012
# 2              Online              M   9/14/2013  667593514  10/19/2013
# 3              Online              M   9/14/2013  667593514  10/19/2013
# 4             Offline              M   5/15/2015  940995585    6/4/2015
# ...               ...            ...         ...        ...         ...
# 1500009        Online              L  10/10/2012  440306556  11/20/2012
# 1500010        Online              L   12/5/2016  937431466   12/8/2016
# 1500011       Offline              C  11/19/2011  274930989  12/13/2011
# 1500012       Offline              L   5/28/2013  153842341   7/16/2013
# 1500013       Offline              H    9/8/2013  371502530  10/13/2013
#
#          Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# 0              1593        9.33       6.92       14862.69    11023.56
# 1              1593        9.33       6.92       14862.69    11023.56
# 2              4611      109.28      35.84      503890.08   165258.24
# 3              4611      109.28      35.84      503890.08   165258.24
# 4               360      421.89     364.69      151880.40   131288.40
# ...             ...         ...        ...            ...         ...
# 1500009        5349      152.58      97.44            NaN         NaN
# 1500010        5657      668.27     502.54     3780403.39  2842868.78
# 1500011        7044      668.27     502.54     4707293.88  3539891.76
# 1500012        4222      205.70     117.11            NaN         NaN
# 1500013        4709       47.45      31.79            NaN         NaN
#
#          Total Profit
# 0             3839.13
# 1             3839.13
# 2           338631.84
# 3           338631.84
# 4            20592.00
# ...               ...
# 1500009           NaN
# 1500010     937534.61
# 1500011    1167402.12
# 1500012           NaN
# 1500013           NaN
#
# [1500014 rows x 14 columns]

# %%
# Check Attribute

list(data.columns)
# Out:
# ['Region',
#  'Country',
#  'Item Type',
#  'Sales Channel',
#  'Order Priority',
#  'Order Date',
#  'Order ID',
#  'Ship Date',
#  'Units Sold',
#  'Unit Price',
#  'Unit Cost',
#  'Total Revenue',
#  'Total Cost',
#  'Total Profit']

# %%
# Descriptive Statistics

data.describe().round(2)
# Out:
#            Order ID  Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.500014e+06  1500014.00  1500014.00  1500014.00     1500009.00
# mean   5.500679e+08     4999.30      266.05      187.55     1329889.20
# std    2.599833e+08     2885.55      217.00      175.67     1468814.34
# min    1.000012e+08        1.00        9.33        6.92           9.33
# 25%    3.246868e+08     2501.00       81.73       35.84      277718.54
# 50%    5.497915e+08     4998.00      154.06       97.44      785329.26
# 75%    7.756273e+08     7498.00      421.89      263.33     1821933.36
# max    9.999999e+08    10000.00      668.27      524.96     6682700.00
#
#        Total Cost  Total Profit
# count  1500009.00  1.500009e+06
# mean    937489.14  5.939205e+07
# std    1149109.12  7.144790e+10
# min          6.92  2.410000e+00
# 25%     161817.60  9.506640e+04
# 50%     467357.49  2.813704e+05
# 75%    1196571.52  5.654252e+05
# max    5249600.00  8.750000e+13

# %%
# Info Dataframe

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500014 entries, 0 to 1500013
# Data columns (total 14 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   Region          1500012 non-null  object
#  1   Country         1500008 non-null  object
#  2   Item Type       1500013 non-null  object
#  3   Sales Channel   1500013 non-null  object
#  4   Order Priority  1500014 non-null  object
#  5   Order Date      1500014 non-null  object
#  6   Order ID        1500014 non-null  int64
#  7   Ship Date       1500014 non-null  object
#  8   Units Sold      1500014 non-null  int64
#  9   Unit Price      1500014 non-null  float64
#  10  Unit Cost       1500014 non-null  float64
#  11  Total Revenue   1500009 non-null  float64
#  12  Total Cost      1500009 non-null  float64
#  13  Total Profit    1500009 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 160.2+ MB

# %% [markdown]
# Prepare Data

# %%
# Delete Rows with a Missing value in the column Country

data = data[data["Country"].notnull()]

# %%
# Rename Columns

data = data.rename(columns = {"Item Type" : "Item_Type",
                              "Sales Channel" : "Sales_Channel",
                              "Order Priority" : "Order_Priority",
                             "Order Date" : "Order_Date",
                              "Order ID" : "Order_ID",
                              "Ship Date" : "Ship_Date",
                              "Units Sold" : "Units_Sold",
                              "Unit Price" : "Unit_Price",
                              "Unit Cost" : "Unit_Cost",
                              "Total Revenue" : "Total_Revenue",
                              "Total Cost" : "Total_Cost",
                              "Total Profit" : "Total_Profit"
                             })

# %%
list(data.columns)
# Out:
# ['Region',
#  'Country',
#  'Item_Type',
#  'Sales_Channel',
#  'Order_Priority',
#  'Order_Date',
#  'Order_ID',
#  'Ship_Date',
#  'Units_Sold',
#  'Unit_Price',
#  'Unit_Cost',
#  'Total_Revenue',
#  'Total_Cost',
#  'Total_Profit']

# %%
# Create new column
# Add Column %Margin 

data["%Margin"] = ((data["Total_Profit"] / data["Total_Revenue"])*100).round(2)

# %%
data.head()
# Out:
#                          Region           Country Item_Type Sales_Channel  \
# 0            Sub-Saharan Africa      South Africa    Fruits       Offline
# 1            Sub-Saharan Africa      South Africa    Fruits       Offline
# 2  Middle East and North Africa           Morocco   Clothes        Online
# 3  Middle East and North Africa           Morocco   Clothes        Online
# 4         Australia and Oceania  Papua New Guinea      Meat       Offline
#
#   Order_Priority Order_Date   Order_ID   Ship_Date  Units_Sold  Unit_Price  \
# 0              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 2              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 3              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 4              M  5/15/2015  940995585    6/4/2015         360      421.89
#
#    Unit_Cost  Total_Revenue  Total_Cost  Total_Profit  %Margin
# 0       6.92       14862.69    11023.56       3839.13    25.83
# 1       6.92       14862.69    11023.56       3839.13    25.83
# 2      35.84      503890.08   165258.24     338631.84    67.20
# 3      35.84      503890.08   165258.24     338631.84    67.20
# 4     364.69      151880.40   131288.40      20592.00    13.56

# %%
# Create a function -> Are sales good or bad ?

def if_condition(row):
    if row["%Margin"] > 30:
        val = "good"
    else:
        val = "bad"
    return val

# %%
# Create new column
# Add Column Dicision 

data["Dicision"] = data.apply(if_condition, axis = 1) # axis = 1 -> columns

# %%
data.head()
# Out:
#                          Region           Country Item_Type Sales_Channel  \
# 0            Sub-Saharan Africa      South Africa    Fruits       Offline
# 1            Sub-Saharan Africa      South Africa    Fruits       Offline
# 2  Middle East and North Africa           Morocco   Clothes        Online
# 3  Middle East and North Africa           Morocco   Clothes        Online
# 4         Australia and Oceania  Papua New Guinea      Meat       Offline
#
#   Order_Priority Order_Date   Order_ID   Ship_Date  Units_Sold  Unit_Price  \
# 0              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 2              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 3              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 4              M  5/15/2015  940995585    6/4/2015         360      421.89
#
#    Unit_Cost  Total_Revenue  Total_Cost  Total_Profit  %Margin Dicision
# 0       6.92       14862.69    11023.56       3839.13    25.83      bad
# 1       6.92       14862.69    11023.56       3839.13    25.83      bad
# 2      35.84      503890.08   165258.24     338631.84    67.20     good
# 3      35.84      503890.08   165258.24     338631.84    67.20     good
# 4     364.69      151880.40   131288.40      20592.00    13.56      bad

# %%
# Plot 

sns.lmplot(x = "Total_Revenue", y = "Total_Profit", data = data, ci= None) # CI = confident interval 

# Found an Outlier!

# %%
# Outlier

data.loc[data['Total_Profit'].idxmax()]
# Out:
# Region            Sub-Saharan Africa
# Country                        Ghana
# Item_Type            Office Supplies
# Sales_Channel                    NaN
# Order_Priority                     L
# Order_Date                 3/23/2017
# Order_ID                   601245963
# Ship_Date                  4/15/2017
# Units_Sold                       896
# Unit_Price                    651.21
# Unit_Cost                     524.96
# Total_Revenue              583484.16
# Total_Cost                 470364.16
# Total_Profit        87500000000000.0
# %Margin           14996122602.540001
# Dicision                        good
# Name: 1500003, dtype: object

# %%
# Check Column Total_Profit
# Top 5 of Total_Profit

data.sort_values("Total_Profit", ascending = False).head()
# Out:
#                      Region      Country        Item_Type Sales_Channel  \
# 1500003  Sub-Saharan Africa        Ghana  Office Supplies           NaN
# 1500005  Sub-Saharan Africa       Uganda    Personal Care        Online
# 897995                 Asia     Maldives        Cosmetics        Online
# 1279511                Asia   Kyrgyzstan        Cosmetics       Offline
# 969307   Sub-Saharan Africa  South Sudan        Cosmetics       Offline
#
#         Order_Priority Order_Date   Order_ID  Ship_Date  Units_Sold  \
# 1500003              L  3/23/2017  601245963  4/15/2017         896
# 1500005              M  6/19/2014  539471471  7/21/2014         451
# 897995               H  4/12/2016  340228402  5/23/2016       10000
# 1279511              H  2/28/2016  952044570  3/18/2016       10000
# 969307               L   4/3/2016  462591636  4/30/2016       10000
#
#          Unit_Price  Unit_Cost  Total_Revenue  Total_Cost  Total_Profit  \
# 1500003      651.21     524.96      583484.16   470364.16  8.750000e+13
# 1500005       81.73      56.67       36860.23    25558.17  1.000000e+12
# 897995       437.20     263.33     4372000.00  2633300.00  1.738700e+06
# 1279511      437.20     263.33     4372000.00  2633300.00  1.738700e+06
# 969307       437.20     263.33     4372000.00  2633300.00  1.738700e+06
#
#               %Margin Dicision
# 1500003  1.499612e+10     good
# 1500005  2.712951e+09     good
# 897995   3.977000e+01     good
# 1279511  3.977000e+01     good
# 969307   3.977000e+01     good

# %%
# Drop an Outlier 

data = data.drop(1500005)
data = data.drop(1500003)

# %%
data.sort_values("Total_Profit", ascending = False).head()
# Out:
#                      Region     Country  Item_Type Sales_Channel  \
# 275470   Sub-Saharan Africa     Senegal  Cosmetics        Online
# 829606               Europe     Armenia  Cosmetics       Offline
# 1279511                Asia  Kyrgyzstan  Cosmetics       Offline
# 1180739              Europe      Sweden  Cosmetics       Offline
# 583126                 Asia    Maldives  Cosmetics        Online
#
#         Order_Priority Order_Date   Order_ID  Ship_Date  Units_Sold  \
# 275470               M  2/18/2016  174407804  2/22/2016       10000
# 829606               C  4/21/2016  217865169  4/26/2016       10000
# 1279511              H  2/28/2016  952044570  3/18/2016       10000
# 1180739              L  6/12/2016  383685767  7/24/2016       10000
# 583126               H  4/11/2016  340228402  5/22/2016       10000
#
#          Unit_Price  Unit_Cost  Total_Revenue  Total_Cost  Total_Profit  \
# 275470        437.2     263.33      4372000.0   2633300.0     1738700.0
# 829606        437.2     263.33      4372000.0   2633300.0     1738700.0
# 1279511       437.2     263.33      4372000.0   2633300.0     1738700.0
# 1180739       437.2     263.33      4372000.0   2633300.0     1738700.0
# 583126        437.2     263.33      4372000.0   2633300.0     1738700.0
#
#          %Margin Dicision
# 275470     39.77     good
# 829606     39.77     good
# 1279511    39.77     good
# 1180739    39.77     good
# 583126     39.77     good

# %%
# Check Column Total_Revenue

data.sort_values("Total_Revenue", ascending = False).head()
# Out:
#                      Region                 Country  Item_Type Sales_Channel  \
# 468659   Sub-Saharan Africa                 Comoros  Household        Online
# 142999   Sub-Saharan Africa                 Senegal  Household        Online
# 1099878              Europe  Bosnia and Herzegovina  Household        Online
# 1085903              Europe                  Sweden  Household       Offline
# 803322   Sub-Saharan Africa                Zimbabwe  Household       Offline
#
#         Order_Priority Order_Date   Order_ID  Ship_Date  Units_Sold  \
# 468659               L  6/26/2011  546093308   7/3/2011       10000
# 142999               C  2/24/2011  459178578   3/2/2011       10000
# 1099878              M   6/9/2011  790819776   7/7/2011       10000
# 1085903              C  6/18/2011  668456542  7/31/2011       10000
# 803322               H   7/5/2011  423730075  7/26/2011       10000
#
#          Unit_Price  Unit_Cost  Total_Revenue  Total_Cost  Total_Profit  \
# 468659       668.27     502.54      6682700.0   5025400.0     1657300.0
# 142999       668.27     502.54      6682700.0   5025400.0     1657300.0
# 1099878      668.27     502.54      6682700.0   5025400.0     1657300.0
# 1085903      668.27     502.54      6682700.0   5025400.0     1657300.0
# 803322       668.27     502.54      6682700.0   5025400.0     1657300.0
#
#          %Margin Dicision
# 468659      24.8      bad
# 142999      24.8      bad
# 1099878     24.8      bad
# 1085903     24.8      bad
# 803322      24.8      bad

# %%
# Check Column %Margin 

data.sort_values("%Margin", ascending = False).head()
# Out:
#                                     Region               Country Item_Type  \
# 1092717  Central America and the Caribbean  Antigua and Barbuda    Clothes
# 1244997                             Europe                France   Clothes
# 398974                              Europe                France   Clothes
# 1245020                 Sub-Saharan Africa               Eritrea   Clothes
# 158959   Central America and the Caribbean                Panama   Clothes
#
#         Sales_Channel Order_Priority  Order_Date   Order_ID   Ship_Date  \
# 1092717       Offline              H  12/23/2016  202264583   1/12/2017
# 1244997       Offline              C  11/21/2012  334083354  12/10/2012
# 398974         Online              M   9/15/2013  835613095  10/14/2013
# 1245020       Offline              C  10/31/2015  608909356  11/28/2015
# 158959        Offline              L   6/27/2010  991353738   7/15/2010
#
#          Units_Sold  Unit_Price  Unit_Cost  Total_Revenue  Total_Cost  \
# 1092717        3440      109.28      35.84      375923.20   123289.60
# 1244997        1543      109.28      35.84      168619.04    55301.12
# 398974         5339      109.28      35.84      583445.92   191349.76
# 1245020        8665      109.28      35.84      946911.20   310553.60
# 158959         2456      109.28      35.84      268391.68    88023.04
#
#          Total_Profit  %Margin Dicision
# 1092717     252633.60     67.2     good
# 1244997     113317.92     67.2     good
# 398974      392096.16     67.2     good
# 1245020     636357.60     67.2     good
# 158959      180368.64     67.2     good

# %%
# Last 5 rows of data

data.tail()
# Out:
#                                Region   Country        Item_Type  \
# 1500006            Sub-Saharan Africa  Zimbabwe  Office Supplies
# 1500008         Australia and Oceania   Vanuatu           Fruits
# 1500009                          Asia     India           Snacks
# 1500012                          Asia    Brunei           Cereal
# 1500013  Middle East and North Africa    Israel        Beverages
#
#         Sales_Channel Order_Priority  Order_Date   Order_ID   Ship_Date  \
# 1500006       Offline              C   3/28/2011  953361213    4/8/2011
# 1500008        Online              C   11/3/2013  571997869  11/11/2013
# 1500009        Online              L  10/10/2012  440306556  11/20/2012
# 1500012       Offline              L   5/28/2013  153842341   7/16/2013
# 1500013       Offline              H    9/8/2013  371502530  10/13/2013
#
#          Units_Sold  Unit_Price  Unit_Cost  Total_Revenue  Total_Cost  \
# 1500006        9623      651.21     524.96            NaN         NaN
# 1500008        5735        9.33       6.92            NaN         NaN
# 1500009        5349      152.58      97.44            NaN         NaN
# 1500012        4222      205.70     117.11            NaN         NaN
# 1500013        4709       47.45      31.79            NaN         NaN
#
#          Total_Profit  %Margin Dicision
# 1500006           NaN      NaN      bad
# 1500008           NaN      NaN      bad
# 1500009           NaN      NaN      bad
# 1500012           NaN      NaN      bad
# 1500013           NaN      NaN      bad

# %%
# Missing Value (NaN, N/A) in Total Revenue, Total Cost, Total profit and %Margin 
data.isnull().sum()
# Out:
# Region            1
# Country           0
# Item_Type         0
# Sales_Channel     0
# Order_Priority    0
# Order_Date        0
# Order_ID          0
# Ship_Date         0
# Units_Sold        0
# Unit_Price        0
# Unit_Cost         0
# Total_Revenue     5
# Total_Cost        5
# Total_Profit      5
# %Margin           5
# Dicision          0
# dtype: int64

# %%
# Manipulate Data
# Total_Revenue = Unit_Price x Units_Sold 
# Total_Cost = Unit_Cost x Units_Sold
# Total_Profit = Total_Revenue - Total_Cost
# %Margin = Total_Profit / Total_Revenue

data["Total_Revenue"] = (data["Units_Sold"] * data["Unit_Price"]).round(2) 
data["Total_Cost"] = (data["Units_Sold"] * data["Unit_Cost"]).round(2)
data["Total_Profit"] = (data["Total_Revenue"] - data["Total_Cost"]).round(2)
data["%Margin"] = ((data["Total_Profit"] / data["Total_Revenue"]) *100).round(2)

# %%
data.info
# Out:
# <bound method DataFrame.info of                                Region           Country        Item_Type  \
# 0                  Sub-Saharan Africa      South Africa           Fruits
# 1                  Sub-Saharan Africa      South Africa           Fruits
# 2        Middle East and North Africa           Morocco          Clothes
# 3        Middle East and North Africa           Morocco          Clothes
# 4               Australia and Oceania  Papua New Guinea             Meat
# ...                               ...               ...              ...
# 1500006            Sub-Saharan Africa          Zimbabwe  Office Supplies
# 1500008         Australia and Oceania           Vanuatu           Fruits
# 1500009                          Asia             India           Snacks
# 1500012                          Asia            Brunei           Cereal
# 1500013  Middle East and North Africa            Israel        Beverages
#
#         Sales_Channel Order_Priority  Order_Date   Order_ID   Ship_Date  \
# 0             Offline              M   7/27/2012  443368995   7/28/2012
# 1             Offline              M   7/27/2012  443368995   7/28/2012
# 2              Online              M   9/14/2013  667593514  10/19/2013
# 3              Online              M   9/14/2013  667593514  10/19/2013
# 4             Offline              M   5/15/2015  940995585    6/4/2015
# ...               ...            ...         ...        ...         ...
# 1500006       Offline              C   3/28/2011  953361213    4/8/2011
# 1500008        Online              C   11/3/2013  571997869  11/11/2013
# 1500009        Online              L  10/10/2012  440306556  11/20/2012
# 1500012       Offline              L   5/28/2013  153842341   7/16/2013
# 1500013       Offline              H    9/8/2013  371502530  10/13/2013
#
#          Units_Sold  Unit_Price  Unit_Cost  Total_Revenue  Total_Cost  \
# 0              1593        9.33       6.92       14862.69    11023.56
# 1              1593        9.33       6.92       14862.69    11023.56
# 2              4611      109.28      35.84      503890.08   165258.24
# 3              4611      109.28      35.84      503890.08   165258.24
# 4               360      421.89     364.69      151880.40   131288.40
# ...             ...         ...        ...            ...         ...
# 1500006        9623      651.21     524.96     6266593.83  5051690.08
# 1500008        5735        9.33       6.92       53507.55    39686.20
# 1500009        5349      152.58      97.44      816150.42   521206.56
# 1500012        4222      205.70     117.11      868465.40   494438.42
# 1500013        4709       47.45      31.79      223442.05   149699.11
#
#          Total_Profit  %Margin Dicision
# 0             3839.13    25.83      bad
# 1             3839.13    25.83      bad
# 2           338631.84    67.20     good
# 3           338631.84    67.20     good
# 4            20592.00    13.56      bad
# ...               ...      ...      ...
# 1500006    1214903.75    19.39      bad
# 1500008      13821.35    25.83      bad
# 1500009     294943.86    36.14      bad
# 1500012     374026.98    43.07      bad
# 1500013      73742.94    33.00      bad
#
# [1500006 rows x 16 columns]>

# %%
data.isnull().sum()
# Out:
# Region            1
# Country           0
# Item_Type         0
# Sales_Channel     0
# Order_Priority    0
# Order_Date        0
# Order_ID          0
# Ship_Date         0
# Units_Sold        0
# Unit_Price        0
# Unit_Cost         0
# Total_Revenue     0
# Total_Cost        0
# Total_Profit      0
# %Margin           0
# Dicision          0
# dtype: int64

# %%
# Check index that Region is null

data[data["Region"].isnull()]
# Out:
#         Region   Country  Item_Type Sales_Channel Order_Priority Order_Date  \
# 1500004    NaN  Tanzania  Cosmetics       Offline              L  5/23/2016
#
#           Order_ID  Ship_Date  Units_Sold  Unit_Price  Unit_Cost  \
# 1500004  739008080  5/24/2016        7768       437.2     263.33
#
#          Total_Revenue  Total_Cost  Total_Profit  %Margin Dicision
# 1500004      3396169.6  2045547.44    1350622.16    39.77     good

# %%
# Create new column
# Add Column Year 

data["Year"] = pd.DatetimeIndex(data["Order_Date"]).year

# %%
# Create new column
# Add Column Month 

data["Month"] = pd.DatetimeIndex(data["Order_Date"]).month

# %%
data
# Out:
#                                Region           Country        Item_Type  \
# 0                  Sub-Saharan Africa      South Africa           Fruits
# 1                  Sub-Saharan Africa      South Africa           Fruits
# 2        Middle East and North Africa           Morocco          Clothes
# 3        Middle East and North Africa           Morocco          Clothes
# 4               Australia and Oceania  Papua New Guinea             Meat
# ...                               ...               ...              ...
# 1500006            Sub-Saharan Africa          Zimbabwe  Office Supplies
# 1500008         Australia and Oceania           Vanuatu           Fruits
# 1500009                          Asia             India           Snacks
# 1500012                          Asia            Brunei           Cereal
# 1500013  Middle East and North Africa            Israel        Beverages
#
#         Sales_Channel Order_Priority  Order_Date   Order_ID   Ship_Date  \
# 0             Offline              M   7/27/2012  443368995   7/28/2012
# 1             Offline              M   7/27/2012  443368995   7/28/2012
# 2              Online              M   9/14/2013  667593514  10/19/2013
# 3              Online              M   9/14/2013  667593514  10/19/2013
# 4             Offline              M   5/15/2015  940995585    6/4/2015
# ...               ...            ...         ...        ...         ...
# 1500006       Offline              C   3/28/2011  953361213    4/8/2011
# 1500008        Online              C   11/3/2013  571997869  11/11/2013
# 1500009        Online              L  10/10/2012  440306556  11/20/2012
# 1500012       Offline              L   5/28/2013  153842341   7/16/2013
# 1500013       Offline              H    9/8/2013  371502530  10/13/2013
#
#          Units_Sold  Unit_Price  Unit_Cost  Total_Revenue  Total_Cost  \
# 0              1593        9.33       6.92       14862.69    11023.56
# 1              1593        9.33       6.92       14862.69    11023.56
# 2              4611      109.28      35.84      503890.08   165258.24
# 3              4611      109.28      35.84      503890.08   165258.24
# 4               360      421.89     364.69      151880.40   131288.40
# ...             ...         ...        ...            ...         ...
# 1500006        9623      651.21     524.96     6266593.83  5051690.08
# 1500008        5735        9.33       6.92       53507.55    39686.20
# 1500009        5349      152.58      97.44      816150.42   521206.56
# 1500012        4222      205.70     117.11      868465.40   494438.42
# 1500013        4709       47.45      31.79      223442.05   149699.11
#
#          Total_Profit  %Margin Dicision  Year  Month
# 0             3839.13    25.83      bad  2012      7
# 1             3839.13    25.83      bad  2012      7
# 2           338631.84    67.20     good  2013      9
# 3           338631.84    67.20     good  2013      9
# 4            20592.00    13.56      bad  2015      5
# ...               ...      ...      ...   ...    ...
# 1500006    1214903.75    19.39      bad  2011      3
# 1500008      13821.35    25.83      bad  2013     11
# 1500009     294943.86    36.14      bad  2012     10
# 1500012     374026.98    43.07      bad  2013      5
# 1500013      73742.94    33.00      bad  2013      9
#
# [1500006 rows x 18 columns]

# %%
# Change the month name to look better

data = data.replace({"Month":{
    1 : "January",
    2 : "Febuary",
    3 : "March",
    4 : "April",
    5 : "May",
    6 : "June",
    7 : "July",
    8 : "August",
    9 : "September",
    10 : "October",
    11 : "November",
    12 : "December"
}})

# %%
data.head()
# Out:
#                          Region           Country Item_Type Sales_Channel  \
# 0            Sub-Saharan Africa      South Africa    Fruits       Offline
# 1            Sub-Saharan Africa      South Africa    Fruits       Offline
# 2  Middle East and North Africa           Morocco   Clothes        Online
# 3  Middle East and North Africa           Morocco   Clothes        Online
# 4         Australia and Oceania  Papua New Guinea      Meat       Offline
#
#   Order_Priority Order_Date   Order_ID   Ship_Date  Units_Sold  Unit_Price  \
# 0              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 2              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 3              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 4              M  5/15/2015  940995585    6/4/2015         360      421.89
#
#    Unit_Cost  Total_Revenue  Total_Cost  Total_Profit  %Margin Dicision  Year  \
# 0       6.92       14862.69    11023.56       3839.13    25.83      bad  2012
# 1       6.92       14862.69    11023.56       3839.13    25.83      bad  2012
# 2      35.84      503890.08   165258.24     338631.84    67.20     good  2013
# 3      35.84      503890.08   165258.24     338631.84    67.20     good  2013
# 4     364.69      151880.40   131288.40      20592.00    13.56      bad  2015
#
#        Month
# 0       July
# 1       July
# 2  September
# 3  September
# 4        May

# %%
# After clean data, plot graph to check again

sns.lmplot(x = "Total_Revenue", y = "Total_Profit", data = data, ci= None)

# %% [markdown]
# Analysis Data

# %%
# Sort Data by Total_Profit

data.sort_values("Total_Profit", ascending = False)
# Out:
#                                     Region      Country  Item_Type  \
# 969307                  Sub-Saharan Africa  South Sudan  Cosmetics
# 691631                              Europe     Slovakia  Cosmetics
# 342508                  Sub-Saharan Africa      Comoros  Cosmetics
# 829606                              Europe      Armenia  Cosmetics
# 1218962                 Sub-Saharan Africa     Botswana  Cosmetics
# ...                                    ...          ...        ...
# 470540                              Europe       Monaco     Fruits
# 576730   Central America and the Caribbean     Honduras     Fruits
# 1239029                               Asia        China     Fruits
# 426590        Middle East and North Africa        Qatar     Fruits
# 575498        Middle East and North Africa     Tunisia      Fruits
#
#         Sales_Channel Order_Priority Order_Date   Order_ID  Ship_Date  \
# 969307        Offline              L   4/3/2016  462591636  4/30/2016
# 691631         Online              M  4/29/2016  995501935  5/19/2016
# 342508         Online              H  6/20/2016  261322534  6/25/2016
# 829606        Offline              C  4/21/2016  217865169  4/26/2016
# 1218962       Offline              C  3/25/2016  584954869   4/6/2016
# ...               ...            ...        ...        ...        ...
# 470540        Offline              C  7/27/2013  700491988   8/2/2013
# 576730         Online              M  6/22/2013  289944922  8/11/2013
# 1239029       Offline              L  7/10/2013  945218455   8/7/2013
# 426590         Online              H  7/18/2013  822855222  8/30/2013
# 575498         Online              M  8/31/2013  211039054  9/14/2013
#
#          Units_Sold  Unit_Price  Unit_Cost  Total_Revenue  Total_Cost  \
# 969307        10000      437.20     263.33     4372000.00  2633300.00
# 691631        10000      437.20     263.33     4372000.00  2633300.00
# 342508        10000      437.20     263.33     4372000.00  2633300.00
# 829606        10000      437.20     263.33     4372000.00  2633300.00
# 1218962       10000      437.20     263.33     4372000.00  2633300.00
# ...             ...         ...        ...            ...         ...
# 470540            1        9.33       6.92           9.33        6.92
# 576730            1        9.33       6.92           9.33        6.92
# 1239029           1        9.33       6.92           9.33        6.92
# 426590            1        9.33       6.92           9.33        6.92
# 575498            1        9.33       6.92           9.33        6.92
#
#          Total_Profit  %Margin Dicision  Year   Month
# 969307     1738700.00    39.77     good  2016   April
# 691631     1738700.00    39.77     good  2016   April
# 342508     1738700.00    39.77     good  2016    June
# 829606     1738700.00    39.77     good  2016   April
# 1218962    1738700.00    39.77     good  2016   March
# ...               ...      ...      ...   ...     ...
# 470540           2.41    25.83      bad  2013    July
# 576730           2.41    25.83      bad  2013    June
# 1239029          2.41    25.83      bad  2013    July
# 426590           2.41    25.83      bad  2013    July
# 575498           2.41    25.83      bad  2013  August
#
# [1500006 rows x 18 columns]

# %%
# Find sum of Total_Profit

Total_Amount = data["Total_Profit"].sum().round(2)
Total_Amount
# Out:
# 588603226440.65

# %%
# Check Total_Profit of Middle East and North Africa [Region]

Middle_East_Amount = data["Total_Profit"][data["Region"] == "Middle East and North Africa"].sum().round(2)
Middle_East_Amount
# Out:
# 73093917891.11

# %%
print("Middle East มี Total Profit : " + str(Middle_East_Amount) + " บาท คิดเป็น : " + str(((Middle_East_Amount/Total_Amount).round(2))*100)+ "% ของทั้งหมด")
# Out:
# Middle East มี Total Profit : 73093917891.11 บาท คิดเป็น : 12.0% ของทั้งหมด

# %%
# Let's see about China [Country]

data["Total_Profit"][data["Country"] == "China"]
# Out:
# 38         731113.75
# 452        174132.12
# 1775       836488.57
# 2260       913671.25
# 2584       248164.03
#              ...
# 1499275     31818.21
# 1499426     92747.06
# 1499732    377138.62
# 1499778    495201.24
# 1499908    187751.70
# Name: Total_Profit, Length: 8134, dtype: float64

# %%
# Sum 

data["Total_Profit"][data["Country"] == "China"].sum()
# Out:
# 3197873920.19

# %%
# Count 

data["Total_Profit"][data["Country"] == "China"].count()
# Out:
# 8134

# %%
# Max

data["Total_Profit"][data["Country"] == "China"].max()
# Out:
# 1737482.91

# %%
# Min

data["Total_Profit"][data["Country"] == "China"].min()
# Out:
# 2.41

# %%
# Mean

data["Total_Profit"][data["Country"] == "China"].mean()
# Out:
# 393148.99436808465

# %%
# Add Comma 

data["Total_Profit"][data["Country"] == "China"].apply(lambda x : "{:,}".format(x))
# Out:
# 38         731,113.75
# 452        174,132.12
# 1775       836,488.57
# 2260       913,671.25
# 2584       248,164.03
#               ...
# 1499275     31,818.21
# 1499426     92,747.06
# 1499732    377,138.62
# 1499778    495,201.24
# 1499908     187,751.7
# Name: Total_Profit, Length: 8134, dtype: object

# %%
# Group by -> like a Pivot Table in Excel

data.groupby(["Year","Month","Item_Type","Order_ID"]).sum()
# Out:
#                                  Units_Sold  Unit_Price  Unit_Cost  \
# Year Month Item_Type  Order_ID
# 2010 April Baby Food  100279700        7694      510.56     318.84
#                       100478398        2646      255.28     159.42
#                       101422536        2037      255.28     159.42
#                       101500213        5023      255.28     159.42
#                       103587186        2605      255.28     159.42
# ...                                     ...         ...        ...
# 2017 May   Vegetables 998649775        3032      308.12     181.86
#                       998727452        4502      154.06      90.93
#                       999593913         907      154.06      90.93
#                       999671590        7786      308.12     181.86
#                       999870288        2692      154.06      90.93
#
#                                  Total_Revenue  Total_Cost  Total_Profit  \
# Year Month Item_Type  Order_ID
# 2010 April Baby Food  100279700     1964124.32  1226577.48     737546.84
#                       100478398      675470.88   421825.32     253645.56
#                       101422536      520005.36   324738.54     195266.82
#                       101500213     1282271.44   800766.66     481504.78
#                       103587186      665004.40   415289.10     249715.30
# ...                                        ...         ...           ...
# 2017 May   Vegetables 998649775      467109.92   275699.76     191410.16
#                       998727452      693578.12   409366.86     284211.26
#                       999593913      139732.42    82473.51      57258.91
#                       999671590     1199511.16   707980.98     491530.18
#                       999870288      414729.52   244783.56     169945.96
#
#                                  %Margin
# Year Month Item_Type  Order_ID
# 2010 April Baby Food  100279700    75.10
#                       100478398    37.55
#                       101422536    37.55
#                       101500213    37.55
#                       103587186    37.55
# ...                                  ...
# 2017 May   Vegetables 998649775    81.96
#                       998727452    40.98
#                       999593913    40.98
#                       999671590    81.96
#                       999870288    40.98
#
# [1285479 rows x 7 columns]

# %%
data.groupby(["Month"])["Total_Profit"].sum().round(2)
# Out:
# Month
# April        5.113972e+10
# August       4.610811e+10
# December     4.626535e+10
# Febuary      4.782907e+10
# January      5.262556e+10
# July         5.240162e+10
# June         5.111819e+10
# March        5.281875e+10
# May          5.280839e+10
# November     4.490212e+10
# October      4.588399e+10
# September    4.470235e+10
# Name: Total_Profit, dtype: float64

# %%
data.groupby(["Country","Item_Type"])["Total_Profit"].sum()
# Out:
# Country      Item_Type
# Afghanistan  Baby Food          3.318292e+08
#              Beverages          5.207576e+07
#              Cereal             2.911936e+08
#              Clothes            2.400776e+08
#              Cosmetics          5.684838e+08
#                                     ...
# Zimbabwe     Meat               1.907654e+08
#              Office Supplies    4.377148e+08
#              Personal Care      8.798709e+07
#              Snacks             1.870779e+08
#              Vegetables         2.121591e+08
# Name: Total_Profit, Length: 2220, dtype: float64

# %%
# Add Comma

data.groupby(["Country","Item_Type"])["Total_Profit"].sum().round(2).apply(lambda x : "{:,}".format(x))
# Out:
# Country      Item_Type
# Afghanistan  Baby Food          331,829,167.72
#              Beverages            52,075,764.0
#              Cereal             291,193,646.79
#              Clothes            240,077,636.64
#              Cosmetics          568,483,787.17
#                                      ...
# Zimbabwe     Meat                190,765,432.0
#              Office Supplies     437,714,810.0
#              Personal Care       87,987,088.42
#              Snacks              187,077,889.2
#              Vegetables          212,159,097.1
# Name: Total_Profit, Length: 2220, dtype: object

# %%
# Export to Excel file

export = data.groupby(["Country","Item_Type"])["Total_Profit"].sum().round(2).apply(lambda x : "{:,}".format(x))

export.to_excel("Total_Profit by Country and Item_Type.xlsx")

# %% [markdown]
# Data Visulization

# %%
# Scatter Plot

sns.scatterplot(x = "Total_Revenue", y = "Total_Profit", data = data)
# Out:
# <AxesSubplot:xlabel='Total_Revenue', ylabel='Total_Profit'>

# %%
# Line Plot

sns.lineplot(x = "Month", y = "Total_Profit", data = data)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Total_Profit'>

# %%
# Bar Plot
sns.barplot(x = "Month", y = "Total_Profit", data = data)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='Total_Profit'>

# %%
sns.barplot(x = "Year", y = "%Margin", data = data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='%Margin'>

# %%
sns.lineplot(x = "Year", y = "%Margin", data = data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='%Margin'>

# %%
sns.lineplot(x = "Year", y = "%Margin", hue =  "Month",data = data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='%Margin'>

# %%
# Increase the scale of the graph

sns.set(rc={'figure.figsize':(10,8.24)})

# %%
sns.lineplot(x = "Year", y = "%Margin", hue =  "Month", data = data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='%Margin'>

# %%
sns.barplot(x = "Year", y = "%Margin", data = data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='%Margin'>

# %%
sns.barplot(x = "Year", y = "Total_Profit", hue = "Month", data = data)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Total_Profit'>

# %%
# Filter Data

margin_top10 = data.sort_values("%Margin", ascending = False).head(10)
margin_top10
# Out:
#                         Region      Country Item_Type Sales_Channel  \
# 1087185                   Asia  South Korea   Clothes       Offline
# 108726      Sub-Saharan Africa     Ethiopia   Clothes        Online
# 1155029  Australia and Oceania   East Timor   Clothes       Offline
# 402045                  Europe      Germany   Clothes        Online
# 402047   Australia and Oceania      Vanuatu   Clothes        Online
# 780931                    Asia      Vietnam   Clothes       Offline
# 1155015     Sub-Saharan Africa         Mali   Clothes       Offline
# 108725      Sub-Saharan Africa     Ethiopia   Clothes        Online
# 1406423     Sub-Saharan Africa      Comoros   Clothes       Offline
# 1043226                 Europe   Montenegro   Clothes       Offline
#
#         Order_Priority  Order_Date   Order_ID  Ship_Date  Units_Sold  \
# 1087185              H    2/9/2014  770135867  2/10/2014        9172
# 108726               C    2/4/2011  222123229  2/17/2011          54
# 1155029              C   3/12/2010  260976207  3/15/2010        7514
# 402045               H   6/30/2013  367244899  7/22/2013        4781
# 402047               M   7/21/2011  586752593   8/4/2011        1986
# 780931               H   2/28/2013  621288716   4/2/2013        1992
# 1155015              H  12/13/2015  175936019  1/23/2016        2233
# 108725               C    2/4/2011  222123229  2/17/2011          54
# 1406423              C  11/28/2010  882583510  12/2/2010        4929
# 1043226              L   5/13/2011  102287709  5/25/2011        8061
#
#          Unit_Price  Unit_Cost  Total_Revenue  Total_Cost  Total_Profit  \
# 1087185      109.28      35.84     1002316.16   328724.48     673591.68
# 108726       109.28      35.84        5901.12     1935.36       3965.76
# 1155029      109.28      35.84      821129.92   269301.76     551828.16
# 402045       109.28      35.84      522467.68   171351.04     351116.64
# 402047       109.28      35.84      217030.08    71178.24     145851.84
# 780931       109.28      35.84      217685.76    71393.28     146292.48
# 1155015      109.28      35.84      244022.24    80030.72     163991.52
# 108725       109.28      35.84        5901.12     1935.36       3965.76
# 1406423      109.28      35.84      538641.12   176655.36     361985.76
# 1043226      109.28      35.84      880906.08   288906.24     591999.84
#
#          %Margin Dicision  Year     Month
# 1087185     67.2     good  2014   Febuary
# 108726      67.2     good  2011   Febuary
# 1155029     67.2     good  2010     March
# 402045      67.2     good  2013      June
# 402047      67.2     good  2011      July
# 780931      67.2     good  2013   Febuary
# 1155015     67.2     good  2015  December
# 108725      67.2     good  2011   Febuary
# 1406423     67.2     good  2010  November
# 1043226     67.2     good  2011       May

# %%
# Bar Chart (Data = margin_top10)

sns.barplot(x = "Country", y = "Total_Profit",hue = "Year",data = margin_top10)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Total_Profit'>

# %%
margin_top10["Total_Revenue"]
# Out:
# 1087185    1002316.16
# 108726        5901.12
# 1155029     821129.92
# 402045      522467.68
# 402047      217030.08
# 780931      217685.76
# 1155015     244022.24
# 108725        5901.12
# 1406423     538641.12
# 1043226     880906.08
# Name: Total_Revenue, dtype: float64

# %%
# Pie Chart
# Define Colors

colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

# %%
# Labels is The data that needs to be displayed

plt.pie(margin_top10["Total_Revenue"], labels = margin_top10["Region"], colors = colors, startangle = 90, autopct = '%1.1f%%') 
# Seaborn (sns) not available to run a pie chart ... We can use MatPlotlib (plt)
# Out:
# ([<matplotlib.patches.Wedge at 0x2805f87b970>,
#   <matplotlib.patches.Wedge at 0x2805f88b070>,
#   <matplotlib.patches.Wedge at 0x2805f88b790>,
#   <matplotlib.patches.Wedge at 0x2805f88beb0>,
#   <matplotlib.patches.Wedge at 0x2805f87b910>,
#   <matplotlib.patches.Wedge at 0x2805f897d30>,
#   <matplotlib.patches.Wedge at 0x2805f8a5490>,
#   <matplotlib.patches.Wedge at 0x2805f8a5bb0>,
#   <matplotlib.patches.Wedge at 0x2805f973310>,
#   <matplotlib.patches.Wedge at 0x2805f973a30>],
#  [Text(-0.7142252708357255, 0.8365896619607696, 'Asia'),
#   Text(-1.087096467668054, 0.1679918747548222, 'Sub-Saharan Africa'),
#   Text(-0.9999733794814301, -0.4583156557750216, 'Australia and Oceania'),
#   Text(-0.2118141534257815, -1.0794140838475843, 'Europe'),
#   Text(0.35394443536457754, -1.0415005216870756, 'Australia and Oceania'),
#   Text(0.6516815109194248, -0.8861778649491171, 'Asia'),
#   Text(0.9008564855863037, -0.6312349739812377, 'Sub-Saharan Africa'),
#   Text(0.9975584450996502, -0.46354843178503846, 'Sub-Saharan Africa'),
#   Text(1.0985652110110093, -0.056164732317856736, 'Sub-Saharan Africa'),
#   Text(0.6400882575358631, 0.8945876271024001, 'Europe')],
#  [Text(-0.38957742045585025, 0.45632163379678337, '22.5%'),
#   Text(-0.5929617096371202, 0.09163193168444846, '0.1%'),
#   Text(-0.5454400251716891, -0.2499903576954663, '18.4%'),
#   Text(-0.11553499277769899, -0.5887713184623186, '11.7%'),
#   Text(0.19306060110795137, -0.5680911936474957, '4.9%'),
#   Text(0.3554626423196863, -0.4833697445177002, '4.9%'),
#   Text(0.49137626486525654, -0.34430998580794786, '5.5%'),
#   Text(0.5441227882361728, -0.25284459915547547, '0.1%'),
#   Text(0.5992173878241869, -0.03063530853701276, '12.1%'),
#   Text(0.3491390495650162, 0.4879568875104, '19.8%')])

# %% [markdown]
# Machine Learning For bussiness

# %%
# Import library 

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Check Version

print(f'sklern version : {sklearn.__version__}')
# Out:
# sklern version : 1.0.2

# %%
# Define a Model (Regression)

model = LinearRegression(normalize = True, n_jobs = -1)
model
# Out:
# LinearRegression(n_jobs=-1, normalize=True)

# %%
# x is dependent variables and  y is independaent variables 

x = data[['Total_Revenue','Total_Cost']]
y = data['%Margin']

# %%
model.fit(x,y)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# LinearRegression(n_jobs=-1, normalize=True)

# %%
# R-square

model.score(x,y)
# Out:
# 0.5312463604621267

# %%
# Slope

model.coef_
# Out:
# array([ 3.38013701e-05, -4.75858163e-05])

# %%
# Intercept

model.intercept_
# Out:
# 33.98553431465948

# %%
# If Total_Revenue = 50,000 and Total_Cost = 20,000
# Predict %Margin 

model.intercept_ + (-3.38013701e-05* 50000)+(-4.75858163e-05*20000)
# Out:
# 31.343749483659483

# %%
# We can use .predict to predict the model -> Easier

model.predict([[50000,20000]])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([34.72388649])

# %%
# If we want to predict 2 variables 

model.predict([[50000,20000],[70000,60000]])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([34.72388649, 33.49648124])

# %%
# Let's create a y_predict for every data

y_predict = model.predict(data[["Total_Revenue","Total_Cost"]]) 
y_predict
# Out:
# array([33.9633485 , 33.9633485 , 43.15376114, ..., 36.77049709,
#        39.81259888, 34.41462739])

# %%
# Create new columns which is the actual value to compare with the model we created

y_actual = data[["%Margin"]]

# %%
# Mean Square Error 

mean_squared_error(y_actual, y_predict)
# Out:
# 81.067238978305

# %%
# Root Mean Square Error 
# Error +- 9.00 , Ex; Actual = 30  Model = 30 +- 9

mean_squared_error(y_actual, y_predict) ** 0.5
# Out:
# 9.0037347238968

# %%
# Create new column
# Add Column Model 

data["Predict_%Margin"] = model.predict(data[["Total_Revenue","Total_Cost"]])
data.drop(["Predict_%Margin"], axis = 1)
data.head()
# Out:
#                          Region           Country Item_Type Sales_Channel  \
# 0            Sub-Saharan Africa      South Africa    Fruits       Offline
# 1            Sub-Saharan Africa      South Africa    Fruits       Offline
# 2  Middle East and North Africa           Morocco   Clothes        Online
# 3  Middle East and North Africa           Morocco   Clothes        Online
# 4         Australia and Oceania  Papua New Guinea      Meat       Offline
#
#   Order_Priority Order_Date   Order_ID   Ship_Date  Units_Sold  Unit_Price  \
# 0              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 1              M  7/27/2012  443368995   7/28/2012        1593        9.33
# 2              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 3              M  9/14/2013  667593514  10/19/2013        4611      109.28
# 4              M  5/15/2015  940995585    6/4/2015         360      421.89
#
#    Unit_Cost  Total_Revenue  Total_Cost  Total_Profit  %Margin Dicision  Year  \
# 0       6.92       14862.69    11023.56       3839.13    25.83      bad  2012
# 1       6.92       14862.69    11023.56       3839.13    25.83      bad  2012
# 2      35.84      503890.08   165258.24     338631.84    67.20     good  2013
# 3      35.84      503890.08   165258.24     338631.84    67.20     good  2013
# 4     364.69      151880.40   131288.40      20592.00    13.56      bad  2015
#
#        Month  Predict_%Margin
# 0       July        33.963348
# 1       July        33.963348
# 2  September        43.153761
# 3  September        43.153761
# 4        May        32.871834

# %%
# Take 1000 samples of the data in Descending order

margin_top1000_model = data.sort_values("%Margin", ascending = False).head(1000)

# %%
# Plot Model vs Actual , Paster is Actual and Muted is Prediction 

f, ax = plt.subplots(figsize=(6, 15))

# Actual

sns.set_color_codes("pastel")
sns.barplot(x = "Year", y = "%Margin", data = margin_top1000_model,
            label = "Actual", color = "r")

# Predict 

sns.set_color_codes("muted")
sns.barplot(x = "Year", y="Predict_%Margin", data = margin_top1000_model,
            label = "Prediction", color = "b")

# Add a legend and informative axis label

ax.set(ylabel = "",
       xlabel = "Actual Vs Prediction")
sns.despine(left = True, bottom = True)
